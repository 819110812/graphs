# %%
from pdfminer import *
from pdfminer.high_level import extract_text

# %%
text = extract_text('../data/part01.pdf')

# %%
text
# Out:
# 'PS3.1\u200b\n\nDICOM PS3.1 2022a - Introduction and Overview\u200b\n\n\x0cPage 2\u200b\n\nA DICOM® publication\u200b\n\nPS3.1: DICOM PS3.1 2022a - Introduction and Overview\u200b\nCopyright © 2022 NEMA\u200b\n\n- Standard -\u200b\n\n\x0cDICOM PS3.1 2022a - Introduction and Overview\u200b\n\nPage 3\u200b\n\nTable of Contents\u200b\n\nNotice and Disclaimer ............................................................................................................................................. 7\u200b\nForeword .............................................................................................................................................................. 9\u200b\n1. Scope and Field of Application ............................................................................................................................. 11\u200b\n1.1. Scope of DICOM ..........................................................................................................................
# ...
